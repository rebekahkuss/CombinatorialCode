# %% [markdown]
# $\Large{\textbf{Lesson 1  -  Task 1}}$

# %% [markdown]
# 1.1) You have a set of shirts {tee, polo, sweater} and a set of pants {jeans, khaki}. An outfit consists of a shirt and a pair of paints. Create a written (by hand) list of all of the possible outcomes. How many are there? Why?

# %% [markdown]
# 1.2) Look at the code below. What do you think this code does? Before you run the code, predict what the output of this code will be.

# %%
Shirts = ['tee','polo','sweater']
Pants = ['jeans','khaki']

outfits = 0
for i in Shirts:
    for j in Pants:
        print(i,j)
        outfits = outfits+1
print(outfits)

# %% [markdown]
# $\Large\textbf{Task 2}$

# %% [markdown]
# 2.1) In the following cell, create some new code that would use 5 different kinds of clothing to create an outfit.

# %% [markdown]
# In the code above, how many outfits did you create?
#
# 2.2) A mathematical expression is a combination of numbers, variables, or operations (like addition, subtraction, multiplication, or division). For example, $3×2×1$,  $2^4-1$, and $(n+1)(n+1)$, are all mathematical expressions.
#
# What is a mathematical expression that represents the number of outputs of your above code?

# %% [markdown]
# 2.3) Can you write some code (still using the outfits context) that would reflect a mathematical expression of $2*3*5*6$ (and not $6*5*3*2$)? Why did you write the code as you did?

# %% [markdown]
# $\Large \textbf{Task 3}$
#
# 3.1) Based on the code below, can you create a tree diagram that shows all possible outfits? Can you explain any similarities between the structure of the tree and your expression? Can you relate the structure of the tree both to the code below and to your list of outcomes?

# %% [raw]
# Shirts = ['tee','polo','sweater','tanktop']
# Pants = ['jeans','khaki', 'shorts']
# Belts = ['brown', 'black']
#
# outfits = 0
# for i in Shirts:
#     for j in Pants:
#         for k in Belts:
#             print(i,j,k)
#             outfits = outfits+1
# print(outfits)

# %% [markdown]
# 3.2) What is the 15th outfit in your list?

# %% [markdown]
# 3.3) How can you change your code to only print the outfits with jeans? How many such jeans outfits do you anticipate there will be?
#
# What is a mathematical expression that represents your code? What would a tree diagram that represents your code look like?

# %% [markdown]
# $\Large \textbf{Task 4}$
#
# 4.1) A license plate consists of six characters.  How many license plates consist of three numbers (from the digits 0 through 5), followed by 3 upper  case  letters (from the letters A, B, C, or D), where repetition of characters is allowed? Write some code to solve this problem.
#
# What is a mathematical expression that represents the number of outputs of your code?

# %% [markdown]
# 4.2) How  many license plates consist of 3 upper case letters (from A, B, C, or D) followed by three numbers (from the digits 0 through 5), where repetition of characters is allowed? Write some code to solve this problem.
#
# What is a mathematical expression that represents the number of outputs of your code?
#
# How  does this mathematical expression relate to the expression you found in problem 4.1?

# %% [markdown]
# 4.3) Consider the following code output. How many outputs do you think there are?
#
# Find a pattern and use it to determine how many outputs there are. What is a mathematical expression that represents the number of outputs of this code?

# %% [raw]
# aaa
# aab
# aac
# aad
# aba
# abb
# abc
# abd
# aca
# acb
# acc
# acd
# ada
# adb
# adc
# add
# baa
# bab
# bac
# bad
# bba
# bbb
# bbc
# bbd
# bca
# bcb
# bcc
# bcd
# bda
# bdb
# bdc
# bdd
# caa
# cab
# cac
# cad
# cba
# cbb
# cbc
# cbd
# cca
# ccb
# ccc
# ccd
# cda
# cdb
# cdc
# cdd
# daa
# dab
# dac
# dad
# dba
# dbb
# dbc
# dbd
# dca
# dcb
# dcc
# dcd
# dda
# ddb
# ddc
# ddd

# %% [markdown]
# $\Large \textbf{Task 5}$
#
#
# 5.1) Using a tree diagram, determine how many possible outcomes there are for flipping a coin 4 times? Explain how the tree diagram shows the total number of outcomes.

# %% [markdown]
# 5.2) Write a program to list (and determine the total number of) all possible outcomes of flipping a coin 4 times.
#
# How is your code related to your tree diagram?
#
# How are the outcomes of your code (the set of outcomes) related to the outcomes in your tree diagram?

# %% [markdown]
# 5.3) Suppose you flip the coin 8 times. How does this change your code? How does this change your outcomes?
#
# What is the total number of possible outcomes now?
#
# What observations do you have about the output of your code (the set of outcomes)?

# %% [markdown]
# 5.4) In the output of your code, what is the 165th outcome in the list? Why?

# %% [markdown]
# 5.5) We claim that if you added another (9th) coin and flipped it, you would double the number of outcomes of 8 coin flips. Why might the total be doubling? Can you use your outcomes or code to explain why the total is doubling?
