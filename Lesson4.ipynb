# %% [markdown]
# $\Large \textbf{Lesson 4 - Task 1}$
#
# 1.1) 1) Can you write some code in order to create a list of all of the ways to arrange 3 of the letters in the word ROCKET?

# %% [markdown]
# $\Large \textbf{Task 2}$
#
# 2.1) Suppose there are 10 horses in a race. How many different possibilities are there for who finishes first, second, and third?
#
#
#
# 2.2) Please write some code so the outcomes list the winning horses from left to right, i.e. the first place horse is in the leftmost spot (so an outcome would look like (first, second, third)).

# %% [markdown]
# $\Large \textbf{Task 3}$
#
# 3.1) Suppose you have three unique hats and five friends. How many ways are there to distribute the three hats among your friends, if no one can have more than one hat?

# %% [raw]
# [Do not scroll past here until you have completed 3.1)]

# %% [markdown]
# 3.2) The code below is your friend Marvin’s attempt to solve the problem with the aid of a computer. Do you think Marvin’s code will correctly solve the problem? Why or why not?

# %% [raw]
# arrangements = 0
# People = ['A','B','C','D','E']
#
# for i in People:
#     for j in People:
#         if j != i:
#             for k in People:
#                 if k != i and k != j:
#                     arrangements = arrangements+1
#                     print(i,j,k)
# print(arrangements)

# %% [markdown]
# 3.3) Below is a portion of the set of outputs from Marvin’s code. What does the output ('A', 'B', 'E') represent? How is this different than the outcome ('B', 'A', 'E')?

# %% [raw]
# ('A', 'B', 'C')
# ('A', 'B', 'D')
# ('A', 'B', 'E')
# ('A', 'C', 'B')
# ('A', 'C', 'D')
# ('A', 'C', 'E')
# ('A', 'D', 'B')
# ('A', 'D', 'C')
# ('A', 'D', 'E')
# ('A', 'E', 'B')
# ('A', 'E', 'C')
# ('A', 'E', 'D')
# ('B', 'A', 'C')
# ('B', 'A', 'D')
# ('B', 'A', 'E')
# ('B', 'C', 'A')
# ('B', 'C', 'D')
# ('B', 'C', 'E')
# ('B', 'D', 'A')
# ('B', 'D', 'C')
# …
# ('E', 'B', 'A')
# ('E', 'B', 'C')
# ('E', 'B', 'D')
# ('E', 'C', 'A')
# ('E', 'C', 'B')
# ('E', 'C', 'D')
# ('E', 'D', 'A')
# ('E', 'D', 'B')
# ('E', 'D', 'C')
# 60

# %% [markdown]
# 3.4) Why is your answer to this hats problem the same as the number of arrangements of 3 letters from the word PHONE?

# %% [markdown]
# $\Large \textbf{Task 4}$
#
# 4.1) How many different arrangements are there of r objects from n distinct objects? How do you know? Justify your answer.
