# %% [markdown]
# $\Large \textbf{Lesson 6 - Task 1}$
#
# 1.1) Consider the code below. Describe what you think the output will be.

# %%
Numbers = {1, 2, 3, 4, 5, 6, 7, 8}
total = 0

for i in Numbers:
    for j in Numbers:
        if j != i:
            for k in Numbers:
                if k != j and k != i:
                    print(i,j,k)
                    total = total+1
print(total)

# %% [markdown]
# 1.2) Now, write a problem that you think this code is answering. Explain your reasoning.

# %% [markdown]
# 1.3) Consider the code below. Describe what you think the output will be.

# %%
Numbers = {1, 2, 3, 4, 5, 6, 7, 8}
total = 0

for i in Numbers:
    for j in Numbers:
        if j > i:
            for k in Numbers:
                if k > j:
                    print(i,j,k)
                    total = total+1
print(total)

# %% [markdown]
# 1.4) Now, write a problem that you think this code is answering. Explain your reasoning.

# %% [markdown]
# $\Large \textbf{Task 2}$
#
# 2.1) We note that you have looked at code involving statements like “j != i” and “j > i.” Consider now the code below. What do you think it’s doing, and what do you think the output will be?

# %%
Numbers = {1, 2, 3, 4, 5, 6, 7, 8}
total = 0

for i in Numbers:
    for j in Numbers:
        if j >= i:
            for k in Numbers:
                if k >= j:
                    print(i,j,k)
                    total = total+1
print(total)

# %% [markdown]
# 2.2) Now, write a problem that you think this code is answer. Explain your work.

# %% [markdown]
# 2.3) How is the output of this code similar to or different from code in 1.1 and 1.3?

# %% [markdown]
# 2.4) Suppose there are 8 different kinds of hot dogs (super, chili, Dodger, footlong, regular, red hot, Chicago, Polish). You are going to buy 3 hot dogs. Can you relate this to the problem you coded in 2.1 above?

# %% [markdown]
# 2.5) Suppose I bought a chili dog and two red hots. What outcome would that correspond to in your list of outcomes from the code in 2.1 above? What would the outcome 345 represent in terms of hot dogs that we bought?

# %% [markdown]
# 2.6) Can you generalize what you found in 2.5 to describe a correspondence between the set of outcomes of buying hot dogs and the set of outcomes in 2.1?

# %% [markdown]
# $\Large \textbf{Task 3}$
#
# 3.1) Can you use or adjust your code from Task 2 to answer the following problem: Suppose I have 6 different kinds of pop and I want to take 4 cans with me. How many ways are there for me to do this?

# %% [markdown]
# 3.2) There are 8 options for hot dogs and 6 options for soda at the Blazer game. If I am buying a total of 4 hot dogs and a total of 3 sodas, how many possibilities are there for what I buy?
