# %% [markdown]
# $\Large\textbf{Lesson 3 - Task 1}$
#
# 1.1) How many ways are there to rearrange 5 people: John, Craig, Brian, Angel, and Dan? How might you count this by hand? How might you count this using a computer?
#
# Below is some code that counts the number of arrangements. What does this code do?

# %%
arrangements = 0
People = ['John', 'Craig', 'Brian', 'Angel', 'Dan']

for p1 in People:
    for p2 in People:
        if p2 != p1:
            for p3 in People:
                if p3 != p1 and p3 != p2:
                    for p4 in People:
                        if p4 != p3 and p4 != p2 and p4 != p1:
                            for p5 in People:
                              if p5!=p4 and p5!=p3 and p5!=p2 and p5!=p1:
                                    arrangements = arrangements+1
                                    print(p1, p1, p3, p4, p5)
print(arrangements)

# %% [markdown]
# 1.2) How many ways are there to arrange the letters in the word PHONE. If you were going to code this, how does the code relate to the previous code in question 1.1)? What do you think the output will look like?
#
# What is a mathematical expression for the total number of outcomes?

# %% [markdown]
# 1.3) Write some code that lists the ways to arrange the letters in the word PHONE. Looking at the output of the code, what are some patterns you observe in the outcomes? How do these patterns in the set of outcomes relate to the code that you wrote? How do they relate to the mathematical expression you found?

# %% [markdown]
# 1.4) What is the 80th outcome in the list?

# %% [markdown]
# 1.5) Here is some code output using the numbers 1-5. Can you find a way to correlate each of these outputs with a unique arrangement of the letters in PHONE?
# What arrangement of PHONE does 35124 correspond to, and why? What would the code look like?

# %% [raw]
# 1 2 3 4 5
# 1 2 3 5 4
# 1 2 4 3 5
# 1 2 4 5 3
# 1 2 5 3 4
# 1 2 5 4 3
# 1 3 2 4 5
# 1 3 2 5 4
# 1 3 4 2 5
# 1 3 4 5 2
# 1 3 5 2 4
# 1 3 5 4 2
# 1 4 2 3 5
# 1 4 2 5 3
# 1 4 3 2 5
# 1 4 3 5 2
# 1 4 5 2 3
# 1 4 5 3 2
# 1 5 2 3 4
# 1 5 2 4 3
# .
# .
# .
# 5 1 4 3 2
# 5 2 1 3 4
# 5 2 1 4 3
# 5 2 3 1 4
# 5 2 3 4 1
# 5 2 4 1 3
# 5 2 4 3 1
# 5 3 1 2 4
# 5 3 1 4 2
# 5 3 2 1 4
# 5 3 2 4 1
# 5 3 4 1 2
# 5 3 4 2 1
# 5 4 1 2 3
# 5 4 1 3 2
# 5 4 2 1 3
# 5 4 2 3 1
# 5 4 3 1 2
# 5 4 3 2 1
# 120

# %% [markdown]
# 1.6) Create some code to list the number of arrangements of the letters in the word ROCKET. How many arrangements to you expect to get, and why do you think that? How will the list of outcomes be structured?
#
# What is the 80th outcome in the list that your code produces?
#
# How would the code and outcomes differ if we instead wanted to arrange the numbers 1 through 6? What is a mathematical expression for the total number of arrangements of the numbers 1 through 6?

# %% [markdown]
# $\Large\textbf{Task 2}$
#
# 2.1) How many arrangements are there of the letters in the word PORTLAND? Can you describe some code that would give you the answer to this problem?

# %% [markdown]
# 2.2) In the 5th nested loop, what does the conditional statement entail/say? Can the statement be simplified or shortened at all?

# %% [markdown]
# 2.3) How many different arrangements are there of n distinct objects in a row? How do you know? Justify your answer.

# %% [markdown]
# 2.4) How does your code in this worksheet reflect your answer in part 2b? In particular, what role does the != sign play in your mathematical formula?
